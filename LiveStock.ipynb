# %% [markdown]
# ## Get Latest Stock Data

# %%
#Get packages
import yfinance as yf

# %% [markdown]
# ### Get stock history

# %%
stocksym = input("Please enter stock symbol : ")
periode = input("Please enter period you want (1d/5d/1mo/3mo/6mo/1y/2y/...max) : ")


sts = yf.Ticker(stocksym)

sts.history(period=periode)
# Out:
# Please enter stock symbol : AAPL
# Please enter period you want (1d/5d/1mo/3mo/6mo/1y/2y/...max) : 1d
#                   Open        High         Low       Close    Volume  \
# Date
# 2020-12-31  134.080002  134.740005  131.720001  132.690002  98990400
# 2020-12-31  134.080002  134.729996  131.729996  132.690002  96942531
#
#             Dividends  Stock Splits
# Date
# 2020-12-31          0             0
# 2020-12-31          0             0

# %% [markdown]
# ### Export history to csv

# %%
import time
ticket = input("Please enter stock symbol : ")
periody = input("Please enter period you want (1d/5d/1mo/3mo/6mo/1y/2y/...max) : ")
intv = input("Please enter interval you want (60m/1d/1wk/1mo/3mo) :")

stockd = yf.download(tickers=ticket,period=periody,interval=intv, threads=True)

stockd.to_csv( ticket +"-"+periody+"-"+"data.csv")
# Out:
# Please enter stock symbol : NVDA
# Please enter period you want (1d/5d/1mo/3mo/6mo/1y/2y/...max) : 1d
# Please enter interval you want (60m/1d/1wk/1mo/3mo) :1d
# [*********************100%***********************]  1 of 1 completed

# %% [markdown]
# ### Stock Chart

# %%
import matplotlib.pyplot as plt
import seaborn

ticket = input("Please enter stock symbol : ")
periody = input("Please enter period you want (1d/5d/1mo/3mo/6mo/1y/2y/...max) : ")
intv = input("Please enter interval you want (60m/1d/1wk/1mo/3mo) :")
tipe = input("Please enter data type (High/Low/Close) : ")

data = yf.Ticker(ticket)

car = data.history(period=periody)

car[tipe].plot(figsize=(16, 9))
# Out:
# Please enter stock symbol : TSLA
# Please enter period you want (1d/5d/1mo/3mo/6mo/1y/2y/...max) : 1y
# Please enter interval you want (60m/1d/1wk/1mo/3mo) :1d
# Please enter data type (High/Low/Close) : Close
# <AxesSubplot:xlabel='Date'>
